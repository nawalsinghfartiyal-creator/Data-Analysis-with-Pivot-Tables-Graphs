# %%
import pandas as pd
df_population_raw = pd.read_csv(r'C:\Users\user\OneDrive\Documents\population_total.csv')
df_population_raw
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4185 rows x 3 columns]

# %% [markdown]
# ### Making a pivot() Table

# %%
# Dropping all null values
df_population_raw.dropna(inplace=True)

# %%
# Making a pivot table
df_pivot = df_population_raw.pivot(index="year" , columns="country" , values="population")

# %%
# Selecting some countries 
df_pivot = df_pivot[['United States' , 'India' , 'China' , 'Indonesia' , 'Brazil']]

# %%
# Showing pivot data 
df_pivot
# Out:
# country  United States         India         China    Indonesia       Brazil
# year
# 1955.0     171685336.0  4.098806e+08  6.122416e+08   77273425.0   62533919.0
# 1960.0     186720571.0  4.505477e+08  6.604081e+08   87751068.0   72179226.0
# 1965.0     199733676.0  4.991233e+08  7.242190e+08  100267062.0   83373530.0
# 1970.0     209513341.0  5.551898e+08  8.276014e+08  114793178.0   95113265.0
# 1975.0     219081251.0  6.231029e+08  9.262409e+08  130680727.0  107216205.0
# 1980.0     229476354.0  6.989528e+08  1.000089e+09  147447836.0  120694009.0
# 1985.0     240499825.0  7.843600e+08  1.075589e+09  164982451.0  135274080.0
# 1990.0     252120309.0  8.732778e+08  1.176884e+09  181413402.0  149003223.0
# 1995.0     265163745.0  9.639226e+08  1.240921e+09  196934260.0  162019896.0
# 2000.0     281710909.0  1.056576e+09  1.290551e+09  211513823.0  174790340.0
# 2005.0     294993511.0  1.147610e+09  1.330776e+09  226289470.0  186127103.0
# ...

# %% [markdown]
# ### Lineplot

# %%
df_pivot.plot(kind='line' , xlabel='Year' , ylabel='population' , title='Population (1995 - 2020)' , figsize=(8 , 4) )
# Out:
# <Axes: title={'center': 'Population (1995 - 2020)'}, xlabel='Year', ylabel='population'>

# %% [markdown]
# ### Barplot

# %% [markdown]
# #### Single Barplot

# %%
import pandas as pd
df_population_raw = pd.read_csv(r'C:\Users\user\OneDrive\Documents\population_total.csv')
df_population_raw
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4185 rows x 3 columns]

# %%
df_population_raw.dropna(inplace=True)

# %%
df_pivot = df_population_raw.pivot(index="year" , columns="country" , values="population")

# %%
df_pivot = df_pivot[['United States' , 'India' , 'China' , 'Indonesia' , 'Brazil']]

# %%
df_pivot
# Out:
# country  United States         India         China    Indonesia       Brazil
# year
# 1955.0     171685336.0  4.098806e+08  6.122416e+08   77273425.0   62533919.0
# 1960.0     186720571.0  4.505477e+08  6.604081e+08   87751068.0   72179226.0
# 1965.0     199733676.0  4.991233e+08  7.242190e+08  100267062.0   83373530.0
# 1970.0     209513341.0  5.551898e+08  8.276014e+08  114793178.0   95113265.0
# 1975.0     219081251.0  6.231029e+08  9.262409e+08  130680727.0  107216205.0
# 1980.0     229476354.0  6.989528e+08  1.000089e+09  147447836.0  120694009.0
# 1985.0     240499825.0  7.843600e+08  1.075589e+09  164982451.0  135274080.0
# 1990.0     252120309.0  8.732778e+08  1.176884e+09  181413402.0  149003223.0
# 1995.0     265163745.0  9.639226e+08  1.240921e+09  196934260.0  162019896.0
# 2000.0     281710909.0  1.056576e+09  1.290551e+09  211513823.0  174790340.0
# 2005.0     294993511.0  1.147610e+09  1.330776e+09  226289470.0  186127103.0
# ...

# %%
# Selecting a year for single barplot
df_pivot_2020 = df_pivot[df_pivot.index.isin([2020])]

# %%
#Showing new dataframe
df_pivot_2020
# Out:
# country  United States         India         China    Indonesia       Brazil
# year
# 2020.0     331002651.0  1.380004e+09  1.439324e+09  273523615.0  212559417.0

# %%
# Transpose datframe
df_pivot_2020 = df_pivot_2020.T

# %%
# Making barplot
df_pivot_2020.plot(kind='bar' , color='red' ,  xlabel='Year' , ylabel='population' , title='Population 2020' , figsize=(7 , 6))
# Out:
# <Axes: title={'center': 'Population 2020'}, xlabel='Year', ylabel='population'>

# %% [markdown]
# #### Barplot grouped by 'n' variable

# %%
# Selecting multiple years
df_pivot_sample = df_pivot[df_pivot.index.isin([1980 , 1990, 2000 , 2010 , 2020])]

# %%
# Making barplot
df_pivot_sample.plot(kind='bar' ,  xlabel='Year' , ylabel='population' )
# Out:
# <Axes: xlabel='Year', ylabel='population'>

# %% [markdown]
# ### Piechart

# %%
df_pivot_2020.rename(columns={2020 : '2020'} , inplace=True)

# %%
df_pivot_2020.plot(kind='pie' , y='2020')
# Out:
# <Axes: ylabel='2020'>

# %% [markdown]
# ### Boxplot

# %% [markdown]
# #### Single Boxplot

# %%
df_pivot['United States'].plot(kind='box' , color='red' , ylabel='Population' )
# Out:
# <Axes: ylabel='Population'>

# %% [markdown]
# ### Multiple Boxplot

# %%
df_pivot.plot(kind='box' , color='red' , ylabel='Population')
# Out:
# <Axes: ylabel='Population'>

# %% [markdown]
# ## Histogram

# %%
df_pivot[['Indonesia' , 'United States']].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Scatter plot

# %%
df_sample = df_population_raw[df_population_raw['country'].isin(['United States' , 'India' , 'China' , 'Indonesia' , 'Brazil'])]

# %%
df_sample.plot(kind='scatter' , x='year' , y='population' , s=50 , color='purple')

# %% [markdown]
# ### Importing Matplotlib

# %% [markdown]
# #### Lineplot

# %%
import pandas as pd
df_population_raw = pd.read_csv(r'C:\Users\user\OneDrive\Documents\population_total.csv')
df_population_raw
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4185 rows x 3 columns]

# %%
df_population_raw.dropna(inplace=True)

# %%
df_pivot = df_population_raw.pivot(index="year" , columns="country" , values="population")

# %%
df_pivot = df_pivot[['United States' , 'India' , 'China' , 'Indonesia' , 'Brazil']]

# %%
df_pivot
# Out:
# country  United States         India         China    Indonesia       Brazil
# year
# 1955.0     171685336.0  4.098806e+08  6.122416e+08   77273425.0   62533919.0
# 1960.0     186720571.0  4.505477e+08  6.604081e+08   87751068.0   72179226.0
# 1965.0     199733676.0  4.991233e+08  7.242190e+08  100267062.0   83373530.0
# 1970.0     209513341.0  5.551898e+08  8.276014e+08  114793178.0   95113265.0
# 1975.0     219081251.0  6.231029e+08  9.262409e+08  130680727.0  107216205.0
# 1980.0     229476354.0  6.989528e+08  1.000089e+09  147447836.0  120694009.0
# 1985.0     240499825.0  7.843600e+08  1.075589e+09  164982451.0  135274080.0
# 1990.0     252120309.0  8.732778e+08  1.176884e+09  181413402.0  149003223.0
# 1995.0     265163745.0  9.639226e+08  1.240921e+09  196934260.0  162019896.0
# 2000.0     281710909.0  1.056576e+09  1.290551e+09  211513823.0  174790340.0
# 2005.0     294993511.0  1.147610e+09  1.330776e+09  226289470.0  186127103.0
# ...

# %%
import matplotlib.pyplot as plt

# %%
df_pivot.plot(kind='line', 
              xlabel='Year' , 
              ylabel='population' ,
              title='Population (1995 - 2020)' , 
              figsize=(8 , 4) )
#Save plot
plt.savefig('my_test.png')
# show plot
plt.show()

# %%
df_pivot.to_excel('pivot_table.xlsx')

# %% [markdown]
# ### Installing Plotly and Cufflinks

# %%
import sys
# !{sys.executable} -m pip install plotly --user

# %%
import plotly
print(plotly.__version__)
# Out:
# 5.24.1

# %%
import pandas as pd
import cufflinks as cf
from IPython.display import display , HTML
cf.set_config_file(sharing='public' , theme='ggplot' , offline='True')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Lineplot (Interactive lineplot)

# %%
import pandas as pd
df_population_raw = pd.read_csv(r'C:\Users\user\OneDrive\Documents\population_total.csv')
df_population_raw
# Out:
#             country    year    population
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4185 rows x 3 columns]

# %%
import plotly.express as px
df_filtered = df_population_raw[df_population_raw['country'].isin(['United States' , 'India' , 'China' , 'Indonesia' , 'Brazil'])]
fig = px.line(df_filtered ,
              x='year',
              y='population',
              color='country' ,
              title='Population from 1995 - 2020')

fig.show()

# %% [markdown]
# ## Barplot

# %%
import plotly.express as px
fig = px.bar(df_filtered , 
              x='year',
              y='population',
              color='country' ,
              title='Population from 1995 - 2020')
fig.show()

# %% [markdown]
# ## Boxplot

# %%
import plotly.express as px
fig = px.box(df_filtered , 
              x='year',
              y='population',
             
              title='Population from 1995 - 2020')
fig.show()

# %% [markdown]
# ## Piechart

# %%
import plotly.express as px
fig = px.pie(df_filtered , 
             names='country' ,
             values='population' , 
             title='Population (1995-2020)' )
fig.show()

# %% [markdown]
# ## Histogram

# %%
import plotly.express as px
df_max = df_population_raw[df_population_raw['country'].isin(['United States' , 'India' , 'China' , 'Indonesia' , 'Brazil'])] 
fig = px.histogram(df_max ,               
                   x='year',
                  y='population',
                  color='country' ,
                  title='Population (1995-2020)')

fig.show()

# %% [markdown]
# ### ScatterPlot

# %%
import plotly.express as px
df_filtered = df_population_raw[df_population_raw['country'].isin(['United States' , 'India' , 'China' , 'Indonesia' , 'Brazil'])]
fig = px.scatter(df_filtered ,
              x='year',
              y='population',
              color='country' ,
              title='Population from 1995 - 2020')

fig.show()

# %% [markdown]
# ### Working on new .csv file

# %%
import pandas as pd
df_cars = pd.read_csv(r'C:\Users\user\OneDrive\Documents\Car_sales.csv')

# %%
df_cars
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
#Selecting columns
df_cars = df_cars[['Manufacturer' , 'Sales_in_thousands' , 'Vehicle_type' , 'Price_in_thousands' , 'Engine_size' , 'Horsepower' , 'Fuel_capacity']]

# %%
df_cars
# Out:
#     Manufacturer  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 0          Acura              16.919    Passenger               21.50
# 1          Acura              39.384    Passenger               28.40
# 2          Acura              14.114    Passenger                 NaN
# 3          Acura               8.588    Passenger               42.00
# 4           Audi              20.397    Passenger               23.99
# ..           ...                 ...          ...                 ...
# 152        Volvo               3.545    Passenger               24.40
# 153        Volvo              15.245    Passenger               27.50
# 154        Volvo              17.531    Passenger               28.80
# 155        Volvo               3.493    Passenger               45.50
# 156        Volvo              18.969    Passenger               36.00
#
#      Engine_size  Horsepower  Fuel_capacity
# 0            1.8       140.0           13.2
# ...

# %%
# Calculate the unique values 
df_cars.nunique()
# Out:
# Manufacturer           30
# Sales_in_thousands    157
# Vehicle_type            2
# Price_in_thousands    152
# Engine_size            31
# Horsepower             66
# Fuel_capacity          55
# dtype: int64

# %% [markdown]
# ### Agg()

# %%
#Calculate the sum of others
df_cars.agg('sum')
# Out:
# Manufacturer          AcuraAcuraAcuraAcuraAudiAudiAudiBMWBMWBMWBuick...
# Sales_in_thousands                                             8320.698
# Vehicle_type          PassengerPassengerPassengerPassengerPassengerP...
# Price_in_thousands                                             4245.567
# Engine_size                                                       477.5
# Horsepower                                                      29008.0
# Fuel_capacity                                                    2800.5
# dtype: object

# %%
#Calculte the mean of numeric data
df_cars[['Sales_in_thousands' , 'Price_in_thousands' , 'Engine_size' , 'Horsepower' , 'Fuel_capacity']].agg('mean')
# Out:
# Sales_in_thousands     52.998076
# Price_in_thousands     27.390755
# Engine_size             3.060897
# Horsepower            185.948718
# Fuel_capacity          17.951923
# dtype: float64

# %%
# Calulate the mean and count values
df_cars[['Sales_in_thousands' , 'Price_in_thousands' , 'Engine_size' , 'Horsepower' , 'Fuel_capacity']].agg(['mean' , 'count'])
# Out:
#        Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# mean            52.998076           27.390755     3.060897  185.948718
# count          157.000000          155.000000   156.000000  156.000000
#
#        Fuel_capacity
# mean       17.951923
# count     156.000000

# %%
# Different agg per column:Calculate the sum and max of 'Price_in_thousands' and sum and mean of 'Sales_in_thousands'
df_cars.agg({'Sales_in_thousands':['sum', 'mean'],
              'Price_in_thousands':['sum' , 'max']})
# Out:
#       Sales_in_thousands  Price_in_thousands
# sum          8320.698000            4245.567
# mean           52.998076                 NaN
# max                  NaN              85.500

# %%
#Aggregrate over columns
df_cars[['Sales_in_thousands' , 'Price_in_thousands']].agg('sum' , axis=1)
# Out:
# 0      38.419
# 1      67.784
# 2      14.114
# 3      50.588
# 4      44.387
#         ...
# 152    27.945
# 153    42.745
# 154    46.331
# 155    48.993
# 156    54.969
# Length: 157, dtype: float64

# %%
#Eqivalent(Nan behaves differently)
df_cars['Price_in_thousands'] + df_cars['Sales_in_thousands']
# Out:
# 0      38.419
# 1      67.784
# 2         NaN
# 3      50.588
# 4      44.387
#         ...
# 152    27.945
# 153    42.745
# 154    46.331
# 155    48.993
# 156    54.969
# Length: 157, dtype: float64

# %%
#Aggregrate different functions and reanme the index of the redulting dataframe
df_cars.agg(x=('Sales_in_thousands' , 'sum') ,
            y=('Price_in_thousands' , 'sum'))
# Out:
#    Sales_in_thousands  Price_in_thousands
# x            8320.698                 NaN
# y                 NaN            4245.567

# %% [markdown]
# ### The Split-Apply-Combine Strategy

# %%
#Count the different type of data
df_cars['Vehicle_type'].value_counts()
# Out:
# Vehicle_type
# Passenger    116
# Car           41
# Name: count, dtype: int64

# %%
#Split data into seperate groups
passenger_filter = df_cars['Vehicle_type']=='Passenger'
car_filter = df_cars['Vehicle_type']=='Car'

# %%
#Apply an operation
passenger_avg = df_cars[passenger_filter]['Sales_in_thousands'].mean()
car_avg = df_cars[car_filter]['Sales_in_thousands'].mean()

# %%
#Combine
pd.DataFrame({'Vehicle_type':['Car' , 'Passenger'] , 
              'Sales_in_thousands':[car_avg , passenger_avg ]})
# Out:
#   Vehicle_type  Sales_in_thousands
# 0          Car           80.622293
# 1    Passenger           43.234345

# %% [markdown]
# ### groupby()

# %%
#Group by 'Vehicle_type' and calculate the mean
df_cars.groupby('Vehicle_type' , as_index=False).mean(numeric_only = True)
# Out:
#   Vehicle_type  Sales_in_thousands  Price_in_thousands  Engine_size  \
# 0          Car           80.622293           26.319975     3.520000
# 1    Passenger           43.234345           27.763200     2.902586
#
#    Horsepower  Fuel_capacity
# 0  186.400000      21.895000
# 1  185.793103      16.592241

# %%
#Group by manufacturer
groupby_obj = df_cars.groupby('Manufacturer')

# %%
groupby_obj

# %%
#Group attributes and keys
groupby_obj.groups.keys()
# Out:
# dict_keys(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet', 'Chrysler', 'Dodge', 'Ford', 'Honda', 'Hyundai', 'Infiniti', 'Jaguar', 'Jeep', 'Lexus', 'Lincoln', 'Mercedes-B', 'Mercury', 'Mitsubishi', 'Nissan', 'Oldsmobile', 'Plymouth', 'Pontiac', 'Porsche', 'Saab', 'Saturn', 'Subaru', 'Toyota', 'Volkswagen', 'Volvo'])

# %%
#Get a specific group within a manufacturer column
groupby_obj.get_group('Ford')
# Out:
#    Manufacturer  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 46         Ford              70.227    Passenger              12.070
# 47         Ford             113.369    Passenger              21.560
# 48         Ford              35.068    Passenger              17.035
# 49         Ford             245.815    Passenger              17.885
# 50         Ford             175.670    Passenger              12.315
# 51         Ford              63.403    Passenger              22.195
# 52         Ford             276.747          Car              31.930
# 53         Ford             155.787          Car              21.410
# 54         Ford             125.338          Car              36.135
# 55         Ford             220.650          Car              12.050
# 56         Ford             540.561          Car              26.935
#
#     Engine_size  Horsepower  Fuel_capacity
# 46          2.0       110.0           12.7
# 47          3.8       190.0           15.7
# ...

# %%
#Group by manufacturer and calculate the mean
df_cars.groupby('Manufacturer').mean(numeric_only=True)
# Out:
#               Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# Manufacturer
# Acura                  19.751250           30.633333     2.925000  200.000000
# Audi                   13.519000           39.980000     2.933333  220.000000
# BMW                    15.501667           33.096667     2.700000  185.333333
# Buick                  60.504750           26.781250     3.625000  206.250000
# Cadillac               22.435600           40.254000     4.500000  256.000000
# Chevrolet              61.596111           20.022778     3.055556  171.111111
# Chrysler               28.817286           23.430833     2.783333  194.833333
# Dodge                  82.740818           24.213636     3.709091  199.545455
# Ford                  183.875909           21.047273     3.327273  170.090909
# Honda                 118.534800           20.277000     2.520000  160.400000
# Hyundai                45.775333           12.165667     1.966667  126.666667
# ...

# %%
#Group by manufacturer and calculate the sum
df_cars.groupby('Manufacturer').sum(numeric_only=True)
# Out:
#               Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# Manufacturer
# Acura                     79.005              91.900         11.7       800.0
# Audi                      40.557             119.940          8.8       660.0
# BMW                       46.505              99.290          8.1       556.0
# Buick                    242.019             107.125         14.5       825.0
# Cadillac                 112.178             201.270         22.5      1280.0
# Chevrolet                554.365             180.205         27.5      1540.0
# Chrysler                 201.721             140.585         16.7      1169.0
# Dodge                    910.149             266.350         40.8      2195.0
# Ford                    2022.635             231.520         36.6      1871.0
# Honda                    592.674             101.385         12.6       802.0
# Hyundai                  137.326              36.497          5.9       380.0
# ...

# %%
#Groupby 'vechile type' and count the values
df_cars.groupby('Vehicle_type').count()
# Out:
#               Manufacturer  Sales_in_thousands  Price_in_thousands  \
# Vehicle_type
# Car                     41                  41                  40
# Passenger              116                 116                 115
#
#               Engine_size  Horsepower  Fuel_capacity
# Vehicle_type
# Car                    40          40             40
# Passenger             116         116            116

# %%
import pandas as pd
df_cars = pd.read_csv(r'C:\Users\user\OneDrive\Documents\Car_sales.csv')
df_cars = df_cars[['Manufacturer' , 'Sales_in_thousands' , 'Vehicle_type' , 'Price_in_thousands' , 'Engine_size' , 'Horsepower' , 'Fuel_capacity']]
df_cars
# Out:
#     Manufacturer  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 0          Acura              16.919    Passenger               21.50
# 1          Acura              39.384    Passenger               28.40
# 2          Acura              14.114    Passenger                 NaN
# 3          Acura               8.588    Passenger               42.00
# 4           Audi              20.397    Passenger               23.99
# ..           ...                 ...          ...                 ...
# 152        Volvo               3.545    Passenger               24.40
# 153        Volvo              15.245    Passenger               27.50
# 154        Volvo              17.531    Passenger               28.80
# 155        Volvo               3.493    Passenger               45.50
# 156        Volvo              18.969    Passenger               36.00
#
#      Engine_size  Horsepower  Fuel_capacity
# 0            1.8       140.0           13.2
# ...

# %%
# Find null values in the column
df_cars.isnull().sum()
# Out:
# Manufacturer          0
# Sales_in_thousands    0
# Vehicle_type          0
# Price_in_thousands    2
# Engine_size           1
# Horsepower            1
# Fuel_capacity         1
# dtype: int64

# %%
# Group by engine size and count values without dropping Nan values
df_cars.groupby('Engine_size' , dropna=False).count()
# Out:
#              Manufacturer  Sales_in_thousands  Vehicle_type  \
# Engine_size
# 1.0                     1                   1             1
# 1.5                     1                   1             1
# 1.6                     1                   1             1
# 1.8                     8                   8             8
# 1.9                     5                   5             5
# 2.0                    17                  17            17
# 2.2                     4                   4             4
# 2.3                     6                   6             6
# 2.4                    11                  11            11
# 2.5                    11                  11            11
# 2.7                     4                   4             4
# 2.8                     3                   3             3
# 2.9                     1                   1             1
# 3.0                    14                  14            14
# ...

# %% [markdown]
# ### Groupby() and Agg()

# %%
# Find the maximum and minimum of each column
df_cars.groupby('Vehicle_type').agg(['min' , 'max'])
# Out:
#              Manufacturer         Sales_in_thousands           \
#                       min     max                min      max
# Vehicle_type
# Car              Cadillac  Toyota              9.126  540.561
# Passenger           Acura   Volvo              0.110  247.994
#
#              Price_in_thousands         Engine_size      Horsepower         \
#                             min     max         min  max        min    max
# Vehicle_type
# Car                      11.528  60.105         2.0  5.7      119.0  300.0
# Passenger                 9.235  85.500         1.0  8.0       55.0  450.0
#
#              Fuel_capacity
#                        min   max
# Vehicle_type
# Car                   15.1  32.0
# Passenger             10.3  23.7

# %%
# Set the name for aggregated column
# find the min Engine_size and max Horsepower
df_cars.groupby('Vehicle_type').agg(min_engine_size =('Engine_size' , 'min'),
                                    max_horsepower=('Horsepower' , 'max'))
# Out:
#               min_engine_size  max_horsepower
# Vehicle_type
# Car                       2.0           300.0
# Passenger                 1.0           450.0

# %%
# Calculate the sum of 'Sales_in_thousands' and mean of 'Price_in_thousands'
df_cars.groupby('Manufacturer').agg(sum_sales=('Sales_in_thousands' , 'sum'),
                                    mean_price=('Price_in_thousands' , 'mean'))
# Out:
#               sum_sales  mean_price
# Manufacturer
# Acura            79.005   30.633333
# Audi             40.557   39.980000
# BMW              46.505   33.096667
# Buick           242.019   26.781250
# Cadillac        112.178   40.254000
# Chevrolet       554.365   20.022778
# Chrysler        201.721   23.430833
# Dodge           910.149   24.213636
# Ford           2022.635   21.047273
# Honda           592.674   20.277000
# Hyundai         137.326   12.165667
# Infiniti         23.713   29.465000
# Jaguar           15.467   42.800000
# Jeep            293.153   20.991667
# Lexus           106.843   44.055000
# Lincoln          85.634   41.690000
# Mercedes-B      117.125   52.916667
# Mercury         237.999   20.748333
# Mitsubishi      180.895   22.167429
# Nissan          399.635   22.360714
# Oldsmobile      178.989   25.622833
# Plymouth         64.001   22.642500
# Pontiac         370.534   22.949167
# Porsche          12.128   62.473333
# ...

# %%
# Same condition but without agg
df_cars.groupby('Manufacturer').sum()['Sales_in_thousands']
# Out:
# Manufacturer
# Acura           79.005
# Audi            40.557
# BMW             46.505
# Buick          242.019
# Cadillac       112.178
# Chevrolet      554.365
# Chrysler       201.721
# Dodge          910.149
# Ford          2022.635
# Honda          592.674
# Hyundai        137.326
# Infiniti        23.713
# Jaguar          15.467
# Jeep           293.153
# Lexus          106.843
# Lincoln         85.634
# Mercedes-B     117.125
# Mercury        237.999
# Mitsubishi     180.895
# Nissan         399.635
# Oldsmobile     178.989
# Plymouth        64.001
# Pontiac        370.534
# Porsche         12.128
# Saab            21.306
# Saturn         168.850
# Subaru          80.135
# Toyota         740.205
# Volkswagen     209.212
# Volvo           75.740
# Name: Sales_in_thousands, dtype: float64

# %%
df_cars.groupby('Manufacturer').mean(numeric_only=True)['Price_in_thousands']
# Out:
# Manufacturer
# Acura         30.633333
# Audi          39.980000
# BMW           33.096667
# Buick         26.781250
# Cadillac      40.254000
# Chevrolet     20.022778
# Chrysler      23.430833
# Dodge         24.213636
# Ford          21.047273
# Honda         20.277000
# Hyundai       12.165667
# Infiniti      29.465000
# Jaguar        42.800000
# Jeep          20.991667
# Lexus         44.055000
# Lincoln       41.690000
# Mercedes-B    52.916667
# Mercury       20.748333
# Mitsubishi    22.167429
# Nissan        22.360714
# Oldsmobile    25.622833
# Plymouth      22.642500
# Pontiac       22.949167
# Porsche       62.473333
# Saab          29.610000
# Saturn        14.271000
# Subaru        21.395000
# Toyota        21.982889
# Volkswagen    17.698333
# Volvo         30.933333
# Name: Price_in_thousands, dtype: float64

# %% [markdown]
# ## Lambda

# %% [markdown]
# #### Get your own function

# %%
# Get actual sales and price values
df_cars.groupby('Manufacturer').sum().apply(lambda x:x*1000)[['Price_in_thousands' , 'Sales_in_thousands']]
# Out:
#               Price_in_thousands  Sales_in_thousands
# Manufacturer
# Acura                    91900.0             79005.0
# Audi                    119940.0             40557.0
# BMW                      99290.0             46505.0
# Buick                   107125.0            242019.0
# Cadillac                201270.0            112178.0
# Chevrolet               180205.0            554365.0
# Chrysler                140585.0            201721.0
# Dodge                   266350.0            910149.0
# Ford                    231520.0           2022635.0
# Honda                   101385.0            592674.0
# Hyundai                  36497.0            137326.0
# Infiniti                 29465.0             23713.0
# Jaguar                   42800.0             15467.0
# Jeep                     62975.0            293153.0
# Lexus                   264330.0            106843.0
# Lincoln                 125070.0             85634.0
# ...

# %%
# Substract values from the mean of each group
df_cars.groupby('Manufacturer').apply(lambda x:x-x.mean(numeric_only=True))
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18240\2390628038.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_cars.groupby('Manufacturer').apply(lambda x:x-x.mean(numeric_only=True))
#                   Engine_size  Fuel_capacity  Horsepower Manufacturer  \
# Manufacturer
# Acura        0      -1.125000      -3.200000  -60.000000          NaN
#              1       0.275000       0.800000   25.000000          NaN
#              2       0.275000       0.800000   25.000000          NaN
#              3       0.575000       1.600000   10.000000          NaN
# Audi         4      -1.133333      -3.133333  -70.000000          NaN
# ...

# %% [markdown]
# ### The Filter() Method

# %%
# Calculate the mean of  'Sales_in_thousands'
df_cars.mean(numeric_only=True)
# Out:
# Sales_in_thousands     52.998076
# Price_in_thousands     27.390755
# Engine_size             3.060897
# Horsepower            185.948718
# Fuel_capacity          17.951923
# dtype: float64

# %%
# filter certain values out based on sum() and return a subset
def filter_fun(x):
    return x['Sales_in_thousands'].sum() > 52

df_filter = df_cars.groupby('Manufacturer').filter(filter_fun)     
df_filter
# Out:
#     Manufacturer  Sales_in_thousands Vehicle_type  Price_in_thousands  \
# 0          Acura              16.919    Passenger              21.500
# 1          Acura              39.384    Passenger              28.400
# 2          Acura              14.114    Passenger                 NaN
# 3          Acura               8.588    Passenger              42.000
# 10         Buick              91.561    Passenger              21.975
# ..           ...                 ...          ...                 ...
# 152        Volvo               3.545    Passenger              24.400
# 153        Volvo              15.245    Passenger              27.500
# 154        Volvo              17.531    Passenger              28.800
# 155        Volvo               3.493    Passenger              45.500
# 156        Volvo              18.969    Passenger              36.000
#
#      Engine_size  Horsepower  Fuel_capacity
# 0            1.8       140.0           13.2
# ...

# %%
df_cars.groupby('Manufacturer').sum()['Sales_in_thousands'].sort_values().head(6)
# Out:
# Manufacturer
# Porsche     12.128
# Jaguar      15.467
# Saab        21.306
# Infiniti    23.713
# Audi        40.557
# BMW         46.505
# Name: Sales_in_thousands, dtype: float64

# %%
df_cars[df_cars['Manufacturer'].isin(['Porsche' , 'Jaguar' , 'Saab' ,  'Infiniti' ,  'Audi'  ,  'BMW'])].shape
# Out:
# (13, 7)

# %%
print(df_cars.shape)
print(df_filter.shape)
# Out:
# (157, 7)
# (144, 7)

# %% [markdown]
# ### Working on Multiple csv file

# %%
import pandas as pd 
df_movies = pd.read_csv(r'C:\Users\user\OneDrive\Documents\IMDb_movies_clean.zip' , low_memory=False)
df_ratings = pd.read_csv(r'C:\Users\user\OneDrive\Documents\IMDb_ratings_clean.zip')

# %%
df_movies = df_movies[['imdb_title_id' , 'title' , 'year' ,  'genre' , 'country']]

# %%
df_ratings = df_ratings[['imdb_title_id' , 'total_votes' , 'mean_vote']]

# %%
df_movies
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country
# 0                        Romance               USA
# 1        Biography, Crime, Drama         Australia
# 2                          Drama  Germany, Denmark
# 3                 Drama, History               USA
# ...

# %%
df_ratings
# Out:
#       imdb_title_id  total_votes  mean_vote
# 0         tt0000009          154        5.9
# 1         tt0000574          589        6.3
# 2         tt0001892          188        6.0
# 3         tt0002101          446        5.3
# 4         tt0002130         2237        6.9
# ...             ...          ...        ...
# 85850     tt9908390          398        5.5
# 85851     tt9911196          724        7.9
# 85852     tt9911774          265        7.8
# 85853     tt9914286          194        9.4
# 85854     tt9914942          102        6.8
#
# [85855 rows x 3 columns]

# %% [markdown]
# ## Concat()

# %% [markdown]
# ##### Concatenate vertically

# %%
df1 = pd.DataFrame({'id': ['A', 'B' , 'C' , 'D'] , 
                    'age': ['30' , '23' , '25' , '22']})
df2 = pd.DataFrame({'id': ['E', 'F' , 'G' , 'H'] , 
                    'age': ['40' , '21' , '19' , '24']})

# %%
pd.concat([df1 , df2] , axis=0 , ignore_index=True)
# Out:
#   id age
# 0  A  30
# 1  B  23
# 2  C  25
# 3  D  22
# 4  E  40
# 5  F  21
# 6  G  19
# 7  H  24

# %% [markdown]
# #### Exercise

# %%
# Extract a 50% sample of original dataframe 'df_movies'
df_sample = df_movies.sample(frac=0.5 , random_state=99)
df_sample
# Out:
#       imdb_title_id                         title  year  \
# 73491     tt4034844                      Terminal  2015
# 903       tt0020987          Hook Line and Sinker  1930
# 29671     tt0116147                         Drive  1997
# 60549     tt1663143                      Fun Size  2012
# 7182      tt0044579          Otto uomini di ferro  1952
# ...             ...                           ...   ...
# 3912      tt0033782               Keeping Company  1940
# 77757     tt5465970                     Attrition  2018
# 14547     tt0065962              Bruciatelo vivo!  1970
# 75460     tt4692234                    O Desolado  2015
# 41709     tt0314620  De schippers van de Kameleon  2003
#
#                            genre                                 country
# 73491                      Drama                                   Japan
# 903              Comedy, Romance                                     USA
# ...

# %%
# Shape of Dataframe that we will concatenate
print(df_movies.shape)
print(df_sample.shape)
# Out:
# (85855, 5)
# (42928, 5)

# %%
# Concetenate df_movies and df_sample (Vertically along rows)
df_concat = pd.concat([df_movies , df_sample] , axis=0)
df_concat
# Out:
#       imdb_title_id                         title  year  \
# 0         tt0000009                    Miss Jerry  1894
# 1         tt0000574   The Story of the Kelly Gang  1906
# 2         tt0001892                Den sorte drøm  1911
# 3         tt0002101                     Cleopatra  1912
# 4         tt0002130                     L'Inferno  1911
# ...             ...                           ...   ...
# 3912      tt0033782               Keeping Company  1940
# 77757     tt5465970                     Attrition  2018
# 14547     tt0065962              Bruciatelo vivo!  1970
# 75460     tt4692234                    O Desolado  2015
# 41709     tt0314620  De schippers van de Kameleon  2003
#
#                            genre                                 country
# 0                        Romance                                     USA
# 1        Biography, Crime, Drama                               Australia
# ...

# %%
# Shape
df_concat.shape
# Out:
# (128783, 5)

# %% [markdown]
# #### Concatenate horizontally

# %%
df1 = pd.DataFrame({'id': ['A', 'B' , 'C' , 'D'] , 
                    'age': ['30' , '23' , '25' , '22']})
df2 = pd.DataFrame({'job': ['Doctor' , 'Statistician' , 'Accountant' , 'Developer']})

# %%
pd.concat([df1 , df2] , axis=1)
# Out:
#   id age           job
# 0  A  30        Doctor
# 1  B  23  Statistician
# 2  C  25    Accountant
# 3  D  22     Developer

# %% [markdown]
# #### Exercise

# %%
# Shape of dataframe that we will concatenate
print(df_movies.shape)
print(df_ratings.shape)
# Out:
# (85855, 5)
# (85855, 3)

# %%
# setting a commom index values for both dataframes (it needs to be same for horizontal concat)
df_movies.set_index('imdb_title_id' , inplace=True)

# %%
df_ratings.set_index('imdb_title_id' , inplace=True)

# %%
# Concatenate the 'df_movies' and 'df_ratings' horizontally
df_concat_horiz = pd.concat([df_movies , df_ratings] , axis=1)
df_concat_horiz
# Out:
#                                         title  year  \
# imdb_title_id
# tt0000009                          Miss Jerry  1894
# tt0000574         The Story of the Kelly Gang  1906
# tt0001892                      Den sorte drøm  1911
# tt0002101                           Cleopatra  1912
# tt0002130                           L'Inferno  1911
# ...                                       ...   ...
# tt9908390                             Le lion  2020
# tt9911196      De Beentjes van Sint-Hildegard  2020
# tt9911774           Padmavyuhathile Abhimanyu  2019
# tt9914286                   Sokagin Çocuklari  2019
# tt9914942          La vida sense la Sara Amat  2019
#
#                                    genre           country  total_votes  \
# imdb_title_id
# tt0000009                        Romance               USA          154
# tt0000574        Biography, Crime, Drama         Australia          589
# tt0001892                          Drama  Germany, Denmark          188
# ...

# %%
# Shape
df_concat_horiz.shape
# Out:
# (85855, 6)

# %% [markdown]
# ### merge()

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'id': ['A', 'B' , 'C' , 'D'] , 
                    'age': ['30' , '23' , '25' , '22']})
df2 = pd.DataFrame({'id': ['C' , 'D' , 'E' , 'F'] , 
                    'job': ['Doctor' , 'Statistician' , 'Accountant' , 'Developer']})

# %% [markdown]
# ##### Inner Join

# %%
df_inner_join = df1.merge(df2 , on='id' , how='inner')

# %%
#Shape
print(df1.shape)
print(df2.shape)
print(df_inner_join.shape)
# Out:
# (4, 2)
# (4, 2)
# (2, 3)

# %% [markdown]
# ##### Exercise

# %%
# Create a merge of 'df_movies' and 'df_ratings'
import pandas as pd
df_movies = pd.read_csv(r'C:\Users\user\OneDrive\Documents\IMDb_movies_clean.zip' , low_memory=False)
df_ratings = pd.read_csv(r'C:\Users\user\OneDrive\Documents\IMDb_ratings_clean.zip')

# %%
df_movies = df_movies[['imdb_title_id' , 'title' , 'year' ,  'genre' , 'country']]

# %%
df_ratings = df_ratings[['imdb_title_id' , 'total_votes' , 'mean_vote']]

# %%
df_movies.merge(df_ratings , on='imdb_title_id' , how='inner')
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country  total_votes  mean_vote
# 0                        Romance               USA          154        5.9
# 1        Biography, Crime, Drama         Australia          589        6.3
# ...

# %% [markdown]
# ###### Another method of using merge()

# %%
pd.merge(df_movies , df_ratings , on='imdb_title_id' , how='inner')
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country  total_votes  mean_vote
# 0                        Romance               USA          154        5.9
# 1        Biography, Crime, Drama         Australia          589        6.3
# ...

# %% [markdown]
# ##### Full join (Outer Join)

# %%
df1 = pd.DataFrame({'id': ['A', 'B' , 'C' , 'D'] , 
                    'age': ['30' , '23' , '25' , '22']})
df2 = pd.DataFrame({'id': ['C' , 'D' , 'E' , 'F'] , 
                    'job': ['Doctor' , 'Statistician' , 'Accountant' , 'Developer']})

# %%
df1.merge(df2 , on='id' , how='outer')
# Out:
#   id  age           job
# 0  A   30           NaN
# 1  B   23           NaN
# 2  C   25        Doctor
# 3  D   22  Statistician
# 4  E  NaN    Accountant
# 5  F  NaN     Developer

# %% [markdown]
# ###### Exercise

# %%
# Create a merge of 'df_movies' and 'df_ratings' (outer join)
df_movies.merge(df_ratings , on='imdb_title_id' , how='outer')
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country  total_votes  mean_vote
# 0                        Romance               USA          154        5.9
# 1        Biography, Crime, Drama         Australia          589        6.3
# ...

# %% [markdown]
# #### Exclusive outer join (Exclusive full join)

# %%
# Outer join
df1.merge(df2 , on='id' , how='outer' )
# Out:
#   id  age           job
# 0  A   30           NaN
# 1  B   23           NaN
# 2  C   25        Doctor
# 3  D   22  Statistician
# 4  E  NaN    Accountant
# 5  F  NaN     Developer

# %%
# indicator = True
df1.merge(df2 , on='id' , how='outer' , indicator=True )
# Out:
#   id  age           job      _merge
# 0  A   30           NaN   left_only
# 1  B   23           NaN   left_only
# 2  C   25        Doctor        both
# 3  D   22  Statistician        both
# 4  E  NaN    Accountant  right_only
# 5  F  NaN     Developer  right_only

# %%
# Adding query (to make 'outer join' to 'exclusive outer join')
df1.merge(df2 , on='id' , how='outer' , indicator=True ).query("(_merge=='left_only') or (_merge=='right_only')")
# Out:
#   id  age         job      _merge
# 0  A   30         NaN   left_only
# 1  B   23         NaN   left_only
# 4  E  NaN  Accountant  right_only
# 5  F  NaN   Developer  right_only

# %% [markdown]
# ##### Exercise

# %%
# Join 'df_movies' and 'df_ratings' to exclusive outer
df_movies.merge(df_ratings , on='imdb_title_id' , how='outer')
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country  total_votes  mean_vote
# 0                        Romance               USA          154        5.9
# 1        Biography, Crime, Drama         Australia          589        6.3
# ...

# %%
# indicator=True
df_movies.merge(df_ratings , on='imdb_title_id' , how='outer' , indicator=True)
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country  total_votes  mean_vote  \
# 0                        Romance               USA          154        5.9
# 1        Biography, Crime, Drama         Australia          589        6.3
# ...

# %%
# Adding query
df_movies.merge(df_ratings , on='imdb_title_id' , how='outer' , indicator=True).query("(_merge=='left_only') or (_merge=='right_only')")
# Out:
# Empty DataFrame
# Columns: [imdb_title_id, title, year, genre, country, total_votes, mean_vote, _merge]
# Index: []

# %% [markdown]
# #### Left join

# %%
df1.merge(df2 , on='id' , how='left')
# Out:
#   id age           job
# 0  A  30           NaN
# 1  B  23           NaN
# 2  C  25        Doctor
# 3  D  22  Statistician

# %% [markdown]
# ###### Exercise

# %%
# extract a 50% sample of df_movies dataframe
df_sample = df_movies.sample(frac=0.5 )
df_sample
# Out:
#       imdb_title_id                        title  year  \
# 43852     tt0370561                     February  2003
# 64657     tt2112210  My Awkward Sexual Adventure  2012
# 29263     tt0114287                      Rob Roy  1995
# 40766     tt0293886                       Olgami  1997
# 47950     tt0465188                   Nuovomondo  2006
# ...             ...                          ...   ...
# 59299     tt1547444                       Baldiz  1975
# 5165      tt0038310       Asu o tsukuru hitobito  1946
# 25810     tt0101524                Sfida d'onore  1991
# 73788     tt4125654             Butterfly Caught  2017
# 84853     tt8898648                  Yabani Asly  2017
#
#                              genre        country
# 43852               Drama, Romance       Thailand
# 64657              Comedy, Romance         Canada
# 29263  Adventure, Biography, Drama             UK
# 40766              Drama, Thriller    South Korea
# ...

# %%
# merge df_sample and df_ratings (left join)
df_left = df_sample.merge(df_ratings , on='imdb_title_id' , how='left')

# %%
# Shape
print(df_sample.shape)
print(df_ratings.shape)
print(df_left.shape)
# Out:
# (42928, 5)
# (85855, 3)
# (42928, 7)

# %% [markdown]
# #### Exclusive left join

# %%
df1.merge(df2 , on='id' , how='outer')
# Out:
#   id  age           job
# 0  A   30           NaN
# 1  B   23           NaN
# 2  C   25        Doctor
# 3  D   22  Statistician
# 4  E  NaN    Accountant
# 5  F  NaN     Developer

# %%
# indicator = True
df1.merge(df2 , on='id', how='outer' , indicator=True)
# Out:
#   id  age           job      _merge
# 0  A   30           NaN   left_only
# 1  B   23           NaN   left_only
# 2  C   25        Doctor        both
# 3  D   22  Statistician        both
# 4  E  NaN    Accountant  right_only
# 5  F  NaN     Developer  right_only

# %%
# Query
df1.merge(df2 , on='id', how='outer' , indicator=True).query("_merge=='left_only'")
# Out:
#   id age  job     _merge
# 0  A  30  NaN  left_only
# 1  B  23  NaN  left_only

# %% [markdown]
# ##### Exercise

# %%
# make a copy of 'df_movies'
df_movies_2 = df_movies.copy()

# %%
# Set the first 1000 value of 'imdb_title_id' as "tt1234567890"
for index in df_movies_2.index:
    if index < 1000:
        df_movies_2.loc[index , 'imdb_title_id'] = 'tt1234567890'

# %%
# merge df_movies_2 and df_ratings (exclusive left only)
df_exclusive_left = df_movies_2.merge(df_ratings , on='imdb_title_id', how='outer' , indicator=True).query("_merge=='left_only'")

# %%
print(df_movies_2.shape)
print(df_exclusive_left.shape)
print(df_ratings.shape)
# Out:
# (85855, 5)
# (1000, 8)
# (85855, 3)

# %% [markdown]
# #### Right join

# %%
import pandas as pd
df1 = pd.DataFrame({'id': ['A', 'B' , 'C' , 'D'] , 
                    'age': ['30' , '23' , '25' , '22']})
df2 = pd.DataFrame({'id': ['C' , 'D' , 'E' , 'F'] , 
                    'job': ['Doctor' , 'Statistician' , 'Accountant' , 'Developer']})

# %%
df1.merge(df2 , on='id' , how='right')
# Out:
#   id  age           job
# 0  C   25        Doctor
# 1  D   22  Statistician
# 2  E  NaN    Accountant
# 3  F  NaN     Developer

# %%
import pandas as pd
df_movies = pd.read_csv(r'C:\Users\user\OneDrive\Documents\IMDb_movies_clean.zip' , low_memory=False)
df_ratings = pd.read_csv(r'C:\Users\user\OneDrive\Documents\IMDb_ratings_clean.zip')

# %%
df_movies = df_movies[['imdb_title_id' , 'title' , 'year' ,  'genre' , 'country']]

# %%
df_ratings = df_ratings[['imdb_title_id' , 'total_votes' , 'mean_vote']]

# %% [markdown]
# ##### Exercise

# %%
# Extract a 30% sample of 'df_ratings_sample'
df_ratings_sample = df_ratings.sample(frac=0.3)

# %%
# merge 'df_movies' and 'df_ratings_sample' (right join)
df_right_merge = df_movies.merge(df_ratings_sample , on='imdb_title_id' , how='right')

# %%
# Shape
print(df_movies.shape)
print(df_ratings_sample.shape)
print(df_right_merge.shape)
# Out:
# (85855, 5)
# (25756, 3)
# (25756, 7)

# %% [markdown]
# #### Exclusive Right join

# %%
# Indicator=True
df1.merge(df2 , on='id' , how='outer' , indicator=True)
# Out:
#   id  age           job      _merge
# 0  A   30           NaN   left_only
# 1  B   23           NaN   left_only
# 2  C   25        Doctor        both
# 3  D   22  Statistician        both
# 4  E  NaN    Accountant  right_only
# 5  F  NaN     Developer  right_only

# %%
# Query
df1.merge(df2 , on='id' , how='outer' , indicator=True).query("_merge=='right_only'")
# Out:
#   id  age         job      _merge
# 4  E  NaN  Accountant  right_only
# 5  F  NaN   Developer  right_only

# %% [markdown]
# ##### Exercise

# %%
# Make a copy of 'df_ratings' dataframe
df_ratings_2 = df_ratings.copy()

# %%
# Set the first 1000 values of 'imdb_title_id' to "tt1234567890"
for index in df_ratings_2.index:
    if index < 1000:
        df_ratings_2.loc[index , 'imdb_title_id'] = 'tt1234567890'

# %%
# Merge 'df_movies' and 'df_ratings_2' in right exclusive join
df_exclusive_right = df_movies.merge(df_ratings_2 , on='imdb_title_id' , how='outer' , indicator=True).query("_merge=='right_only'")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Merge 'df_movies' and 'df_ratings_2' in right exclusive join
# ----> 2 df_exclusive_right = df_movies.merge(df_ratings_2 , on='imdb_title_id' , how='outer' , indicator=True).query("_merge=='right_only'")
#
# NameError: name 'df_movies' is not defined

# %%
print(df_movies.shape)
print(df_ratings_2.shape)
print(df_exclusive_right.shape)
# Out:
# (85855, 5)
# (85855, 3)
# (1000, 8)

# %% [markdown]
# ## The re module

# %%
import re

# %% [markdown]
# ### re.search()

# %%
text = """Hellow World.
I love Python!!!!!
My first lucky number is 987-654-321
My second lucky number is 876-543-210
My third lucky number is 765-432-100
My fourth lucky number is 123-456-123-123-456
"""

# %%
# Return the first match
re.search(r'\d' , text)
# Out:
# <re.Match object; span=(59, 60), match='9'>

# %%
# Flags
re.search(r'^hellow' , text, flags=re.I)
# Out:
# <re.Match object; span=(0, 6), match='Hellow'>

# %% [markdown]
# ### re.findall()

# %%
# Find all the matches
re.findall(r'\d' , text)
# Out:
# ['9',
#  '8',
#  '7',
#  '6',
#  '5',
#  '4',
#  '3',
#  '2',
#  '1',
#  '8',
#  '7',
#  '6',
#  '5',
#  '4',
#  '3',
#  '2',
#  '1',
#  '0',
#  '7',
#  '6',
#  '5',
#  '4',
#  '3',
#  '2',
#  '1',
#  '0',
#  '0',
#  '1',
#  '2',
#  '3',
#  '4',
#  '5',
#  '6',
#  '1',
#  '2',
#  '3',
#  '1',
#  '2',
#  '3',
#  '4',
#  '5',
#  '6']

# %% [markdown]
# #### Exercise

# %%
# Match only puncuation in text 
re.findall(r'[^\w\s]' , text)
# Out:
# ['.',
#  '!',
#  '!',
#  '!',
#  '!',
#  '!',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-',
#  '-']

# %%
# Match the right date format (MM-DD-YYYY)
text= """
13-04-2021
2021-13-04
2021-04-13
"""

# %%
re.findall(r'\d{2}-\d{2}-\d{4}' , text)
# Out:
# ['13-04-2021']

# %%
# match right username format (4-14 characters and only letters and digits)
text='''
username10
abc
10
'''

# %%
re.findall(r'[a-zA-Z0-9]{4,14}' , text)
# Out:
# ['username10']
